# %%
from google import Google

# %%
from research.company_db import *
from research.social import *
from research.li import *
from research.zoominfo import *
import requests
import grequests
from google import Google
from companies import Companies

api_key = ""
domain, name = "guidespark.com","guidespark"

b = Companies()._company_blog(domain)
#GlassDoor()._reviews(domain, api_key, name)
#Companies()._press_releases(name)
#Companies()._news(name)
#Companies()._hiring(name)
#Twitter()._tweets( requests.get("https://twitter.com/guidespark").text)
#Facebook()._daily_news( domain, api_key, name)
#Linkedin()._daily_news( domain, api_key, name)
#Companies()._recent_webpages_published( domain, api_key, name, 1)
#Companies()._press_releases(domain, api_key, name, 1)
# Out:
# guidespark.com
# 0
#                                                  link  \
# 0                     http://www.guidespark.com/blog/
# 1   http://www.guidespark.com/blog/category/blog/p...
# 2   http://www.guidespark.com/blog/category/employ...
# 3   http://www.guidespark.com/blog/category/financ...
# 4   http://www.guidespark.com/blog/carnival-of-hr-...
# 5   http://www.guidespark.com/blog/spooky-truths-e...
# 6   http://www.guidespark.com/blog/trends-next-gen...
# 7   http://www.guidespark.com/blog/hrs-guide-compe...
# 8   http://www.guidespark.com/blog/top-10-tips-eff...
# 9   http://www.guidespark.com/blog/category/onboar...
# 10  http://www.guidespark.com/blog/disruptive-hr-m...
# 11  http://www.guidespark.com/blog/things-thankful...
# 12            http://www.guidespark.com/blog/page/14/
# 13  http://www.guidespark.com/blog/category/compen...
# 14         http://www.guidespark.com/blog/happy-2015/
# 15  http://www.guidespark.com/blog/4-reasons-video...
# ...

# %%
b
# Out:
#                                                  link  \
# 0                     http://www.guidespark.com/blog/
# 1   http://www.guidespark.com/blog/category/blog/p...
# 2   http://www.guidespark.com/blog/category/employ...
# 3   http://www.guidespark.com/blog/category/financ...
# 4   http://www.guidespark.com/blog/carnival-of-hr-...
# 5   http://www.guidespark.com/blog/spooky-truths-e...
# 6   http://www.guidespark.com/blog/trends-next-gen...
# 7   http://www.guidespark.com/blog/hrs-guide-compe...
# 8   http://www.guidespark.com/blog/top-10-tips-eff...
# 9   http://www.guidespark.com/blog/category/onboar...
# 10  http://www.guidespark.com/blog/disruptive-hr-m...
# 11  http://www.guidespark.com/blog/things-thankful...
# 12            http://www.guidespark.com/blog/page/14/
# 13  http://www.guidespark.com/blog/category/compen...
# 14         http://www.guidespark.com/blog/happy-2015/
# 15  http://www.guidespark.com/blog/4-reasons-video...
# ...

# %%
import rethinkdb as r

# %%
conn = r.connect(db="clearspark")

# %%
import nylas
import pandas as pd
import time
from nylas import APIClient
#from nylas.util import generate_id

APP_ID = 'dwgife1rhiw22t8a8gzdmir9b'
APP_SECRET = '6nuzrvbyrbsuwxuzw8nrgtci7'
ACCESS_TOKEN = "aRAdr9eBwOHrlIgbtIuBHocH54zuze"
client = APIClient(APP_ID, APP_SECRET, ACCESS_TOKEN)

ns = client.namespaces[0]
messages = ns.messages.where(**{'from': 'robin@robinsingh.co'})
msg = messages.all()
sent = pd.DataFrame(pd.DataFrame([dict(i) for i in msg]).to.sum()).email.drop_duplicates().tolist()

ms = ns.messages.all()
ct = ns.contacts.all()
cl = ns.calendars.all()
ev = ns.events.all()

ct = pd.DataFrame([dict(i) for i in ct])
cl = pd.DataFrame([dict(i) for i in cl])
ev = pd.DataFrame([dict(i) for i in ev])

# %%
ct[:100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-590880f6139b> in <module>()
# ----> 1 ct[:100]
#
# NameError: name 'ct' is not defined

# %%
class Integration:
    def get_contacts(self):
        """ """
        
    def insert_contacts(self):
        """ """
        
    def enrich_contacts(self):
        """ """

# %%
ct[:10].to_dict("r")
# Out:
# [{'api': <nylas.client.client.APIClient at 0x10bc59c50>,
#   'cls': nylas.client.restful_models.Contact,
#   'email': u'hani@hipstreet.com',
#   'id': u'2nki2kbpge25aowjjzrge83z2',
#   'name': None,
#   'namespace': u'eojrhrnmk1ododkdyw3epxlxj',
#   'namespace_id': u'eojrhrnmk1ododkdyw3epxlxj'},
#  {'api': <nylas.client.client.APIClient at 0x10bc59c50>,
#   'cls': nylas.client.restful_models.Contact,
#   'email': u'info@capitalinvestmentgroup.com',
#   'id': u'30oiineh3rzoucyk3jvg3tn95',
#   'name': None,
#   'namespace': u'eojrhrnmk1ododkdyw3epxlxj',
#   'namespace_id': u'eojrhrnmk1ododkdyw3epxlxj'},
#  {'api': <nylas.client.client.APIClient at 0x10bc59c50>,
#   'cls': nylas.client.restful_models.Contact,
#   'email': u'brendon@joistapp.com',
#   'id': u'7b49hdbiqms37up203u4wo8v2',
#   'name': u'Brendon Sedo',
#   'namespace': u'eojrhrnmk1ododkdyw3epxlxj',
#   'namespace_id': u'eojrhrnmk1ododkdyw3epxlxj'},
#  {'api': <nylas.client.client.APIClient at 0x10bc59c50>,
# ...

# %%
import rethinkdb as r
conn = r.connect(db="clearspark")

# %%
conn = r.connect(db="clearspark")
r.table("user_contacts").insert(ct[:100][["email","name"]].to_dict("r")).run(conn)
# Out:
# {u'deleted': 0,
#  u'errors': 0,
#  u'generated_keys': [u'5ae626eb-7ab6-4faa-96b7-3bc91af58f17',
#   u'd34bf14f-3358-4588-b60a-7c33481d09b7',
#   u'2a8c0c42-61fc-4e66-9952-9d2f9f9d9359',
#   u'64850b8b-af77-41cf-a478-51da66a07470',
#   u'9ec39365-65b6-4102-9da5-ce6b562c00e9',
#   u'ef97ae3b-56e7-4600-987a-c4c62985fad8',
#   u'bcd20b7b-8b65-49f6-8134-4df7efdd4d1b',
#   u'0283eeae-8d7d-48cd-b0c0-f4caf42a1155',
#   u'bcbed13e-e538-4c3b-92f0-b078be82456f',
#   u'f273fe70-4600-46a0-a669-d299bd8390ef'],
#  u'inserted': 10,
#  u'replaced': 0,
#  u'skipped': 0,
#  u'unchanged': 0}

# %%
r.table("users").insert({"name":"Robin Singh","email":"robinsingh.co"}).run(conn)
# Out:
# {u'deleted': 0,
#  u'errors': 0,
#  u'generated_keys': [u'bb49d9b3-5099-4de4-9de4-b7c03646773f'],
#  u'inserted': 1,
#  u'replaced': 0,
#  u'skipped': 0,
#  u'unchanged': 0}

# %%
r.table_create("user_social_profiles", primary_key="email").run(conn)

# %%
r.table_create("companies",primary_key="domain").run(conn)
# Out:
# {u'config_changes': [{u'new_val': {u'db': u'clearspark',
#     u'durability': u'hard',
#     u'id': u'798d2acc-ad9a-4ed2-a501-2d41f577d20b',
#     u'name': u'companies',
#     u'primary_key': u'domain',
#     u'shards': [{u'primary_replica': u'rajvinders_mbp_x9c',
#       u'replicas': [u'rajvinders_mbp_x9c']}],
#     u'write_acks': u'majority'},
#    u'old_val': None}],
#  u'tables_created': 1}

# %%
user_id = "bb49d9b3-5099-4de4-9de4-b7c03646773f"
import clearbit

clearbit.key = 'dc80f4192b73cca928f4e7c284b46573'
for row, i in ct[:200][["email","name"]].iterrows():
    res = clearbit.Enrichment.find(email=i["email"], stream=True)
    #r.table("companies").insert(res["company"]).run(conn)
    domains = {"linkedin":"http://linkedin.com/","twitter":"http://twitter.com/",
               "crunchbase":"http://crunchbase.com/","gravatar":"http://gravatar.com/",
               "github":"http://github.com/","aboutme":"http://about.me/",
               "facebook":"http://facebook.com/","angellist":"http://angel.co/"}

    for _type in ["person","company"]:
        handles = []
        if not res[_type]: continue
        for i in res[_type].keys():
            if type(res[_type][i]) is dict:
                if "handle" in res[_type][i].keys():
                    if res[_type][i]["handle"]:
                        print domains[i]+res[_type][i]["handle"]
                        handles.append(domains[i]+res[_type][i]["handle"])

        if _type == "company":
            res["company"]["handles"] = handles
            res["company"]["user_id"] = user_id
            if res["person"]:            
                res["company"]["email"] = res["person"]["email"]
            r.table("companies").insert(res["company"]).run(conn)
        else:
            res["person"]["handles"] = handles
            res["person"]["user_id"] = user_id
            if res["company"]:
                res["person"]["company_domain"] = res["company"]["domain"]
            r.table("user_social_profiles").insert(res["person"]).run(conn)
# Out:
# http://linkedin.com/pub/hani-henein/29/676/557
# http://twitter.com/hipstreet
# http://linkedin.com/company/hipstreet
# http://facebook.com/hipstreetonline
# http://angel.co/capital-investment-group-1
# http://twitter.com/BrendonSedo
# http://linkedin.com/pub/brendon-sedo/30/258/626
# http://facebook.com/639340656
# http://gravatar.com/brendonsedo
# http://angel.co/brendon-sedo
# http://twitter.com/JoistApp
# http://linkedin.com/company/joist
# http://crunchbase.com/joist
# http://angel.co/joist
# http://twitter.com/Wealthsimple
# http://linkedin.com/company/wealthsimple
# http://crunchbase.com/wealthsimple
# http://facebook.com/wealthsimple
# http://angel.co/wealthsimple
# http://linkedin.com/pub/lewis-katz/4/672/716
# http://facebook.com/lewis.katz.9
# http://angel.co/lewis-katz
# http://linkedin.com/company/clamour
# http://crunchbase.com/clamour
# http://angel.co/clamour-buy-sell-smile
# http://github.com/tchebotarev
# http://about.me/tchebotarev
# http://twitter.com/tchebotarev
# ...

# %%
list(r.table('companies').run(conn))
# Out:
# [{u'company': {u'angellist': {u'blogUrl': None,
#     u'description': None,
#     u'followers': None,
#     u'handle': None,
#     u'id': None},
#    u'category': {u'industry': u'Household Durables',
#     u'industryGroup': u'Consumer Durables & Apparel',
#     u'sector': u'Consumer Discretionary',
#     u'subIndustry': u'Consumer Electronics'},
#    u'crunchbase': {u'handle': None},
#    u'description': u'Hipstreet #Electronics brings you the latest selection of products to enhance your #digital lifestyle needs. http://t.co/LucQK7E4bD',
#    u'domain': u'hipstreet.com',
#    u'domainAliases': [],
#    u'email': u'hani@hipstreet.com',
#    u'emailProvider': False,
#    u'facebook': {u'handle': u'hipstreetonline', u'likes': 4284},
#    u'foundedDate': None,
#    u'geo': {u'city': u'Markham',
#     u'country': u'Canada',
#     u'countryCode': u'CA',
#     u'lat': 43.82395409999999,
#     u'lng': -79.3445277,
#     u'postalCode': u'L3R 2M8',
#     u'state': u'Ontario',
# ...

# %%
_args = [i.split("@")[-1] for i in ct.email.tolist()[:5]]
r.table("companies").get_all(r.args(_args)).run(conn)

# %%
list(r.table("companies").get_all(r.args(["hipstreet.com","lol","lmao"])).run(conn))
# Out:
# [{u'angellist': {u'blogUrl': None,
#    u'description': None,
#    u'followers': None,
#    u'handle': None,
#    u'id': None},
#   u'category': {u'industry': u'Household Durables',
#    u'industryGroup': u'Consumer Durables & Apparel',
#    u'sector': u'Consumer Discretionary',
#    u'subIndustry': u'Consumer Electronics'},
#   u'crunchbase': {u'handle': None},
#   u'description': u'Hipstreet #Electronics brings you the latest selection of products to enhance your #digital lifestyle needs. http://t.co/LucQK7E4bD',
#   u'domain': u'hipstreet.com',
#   u'domainAliases': [],
#   u'emailProvider': False,
#   u'facebook': {u'handle': u'hipstreetonline', u'likes': 4284},
#   u'foundedDate': None,
#   u'geo': {u'city': u'Markham',
#    u'country': u'Canada',
#    u'countryCode': u'CA',
#    u'lat': 43.82395409999999,
#    u'lng': -79.3445277,
#    u'postalCode': u'L3R 2M8',
#    u'state': u'Ontario',
#    u'stateCode': u'ON',
#    u'streetName': u'Denison Street',
# ...

# %%
list(r.table("companies").run(conn))
# Out:
# [{u'angellist': {u'blogUrl': u'http://blog.wealthsimple.com',
#    u'description': u"Wealthsimple is a game-changing financial advisor that makes investing easy, transparent, and low-cost. You get a sophisticated portfolio managed for you, and unlimited support from a dedicated financial advisor. Simple and transparent, Wealthsimple's intuitive platform makes your investments simple and easy to understand. We take the guesswork out of investing, and ensure that you are on the right financial track.",
#    u'followers': 70,
#    u'handle': u'wealthsimple',
#    u'id': 389357},
#   u'category': {u'industry': u'Diversified Financial Services',
#    u'industryGroup': u'Diversified Financials',
#    u'sector': u'Financials',
#    u'subIndustry': None},
#   u'crunchbase': {u'handle': u'wealthsimple'},
# ...

# %%
r = Crawlera().get("http://glassdoor.com/Reviews/GuideSpark-Reviews-E722527.htm?sort.sortType=RD&sort.ascending=false&filter.employmentStatus=REGULAR&filter.employmentStatus=PART_TIME&filter.employmentStatus=UNKNOWN")

# %%
r = requests.get("http://localhost:8950/render.html?url=http://glassdoor.com/Reviews/GuideSpark-Reviews-E722527.htm?sort.sortType=RD&sort.ascending=false&filter.employmentStatus=REGULAR&filter.employmentStatus=PART_TIME&filter.employmentStatus=UNKNOWN")

# %%
tw = BeautifulSoup(html)
tweets = []
for tweet in tw.find_all("li",{"class":"js-stream-item"}):

    timestamp = tweet.find("span", {"class":"js-short-timestamp"})["data-time"]
    text = tweet.find("p",{"class":"tweet-text"}).text
    _hashtags = tweet.find_all("a",{"class":"twitter-hashtag"})
    hashtags = [hashtag.text if hashtag else "" for hashtag in _hashtags]
    _mentions = tweet.find_all("a",{"class":"twitter-atreply"})
    mentions = [reply.text if reply else "" for reply in _mentions]
    _links = tweet.find_all("a",{"class":"twitter-timeline-link"})
    links = [link.text for link in _links]

    _imgs = tweet.find_all("img",{"class":"TwitterPhoto-mediaSource"})
    photos = [img["src"] if img else "" for img in _imgs]
    
    tweet = {"text":text,"hashtags":hashtags,"mentions":mentions,
             "links":links, "photos":photos, "timestamp":timestamp}
    tweets.append(tweet)
tweets = pd.DataFrame(tweets)
return tweets

# %%
tweets
# Out:
# [{'hashtags': [u'#HRTechConf'],
#   'links': [],
#   'mentions': [u'@guidespark', u'@SmartRecruiters'],
#   'photos': [],
#   'text': u'#HRTechConf  having fun in the expo. Stopped by to see the cool kids @guidespark @SmartRecruiters',
#   'timestamp': '1445298392'},
#  {'hashtags': [u'#LinkedIn', u'#HRTechConf'],
#   'links': [u'pic.twitter.com/8KH0SRo7he', u'\n\n\n\n\n'],
#   'mentions': [],
#   'photos': [],
#   'text': u'Liven up your #LinkedIn profile with a new professional pic at Booth #1656! #HRTechConf pic.twitter.com/8KH0SRo7he',
#   'timestamp': '1445297044'},
#  {'hashtags': [u'#HRTech', u'#HRTechConf'],
#   'links': [u'http://ow.ly/TAO0g\xa0'],
#   'mentions': [u'@Josh_Bersin'],
#   'photos': [],
#   'text': u"We're featured in @Josh_Bersin's latest #HRTech report for bringing new ideas & innovative offerings! http://ow.ly/TAO0g\xa0 #HRTechConf",
#   'timestamp': '1445288718'},
#  {'hashtags': [],
#   'links': [u'http://bit.ly/1RSkft3\xa0'],
# ...

# %%
html = requests.get("https://facebook.com/guidespark").text

# %%
r.table_create("user_social_profiles",primary_key="email").run(conn)
# Out:
# {u'config_changes': [{u'new_val': {u'db': u'clearspark',
#     u'durability': u'hard',
#     u'id': u'306b8b18-626c-4807-96ac-c31e98b74b43',
#     u'name': u'user_social_profiles',
#     u'primary_key': u'email',
#     u'shards': [{u'primary_replica': u'rajvinders_mbp_x9c',
#       u'replicas': [u'rajvinders_mbp_x9c']}],
#     u'write_acks': u'majority'},
#    u'old_val': None}],
#  u'tables_created': 1}

# %%
#return google_results
auth = requests.auth.HTTPProxyAuth('robinsingh', '951562nileppez')
proxies = {'http': 'us-il.proxymesh.com:31280'}
un, pw = "customero", "iUyET3ErxR"
CRAWLERA_URL = "http://{0}:{1}@paygo.crawlera.com/fetch?".format(un, pw)
SPLASH_URL = "http://localhost:8950/render.html?"

# %%
url = 'http://webcache.googleusercontent.com/search?q=cache:'+url
url = CRAWLERA_URL + urllib.urlencode({'url':url})
#urls.append(url)
url = urllib.unquote_plus(url)
url = SPLASH_URL + urllib.urlencode({'url': url})

# %%
url = "https://facebook.com/guidespark"
url = 'http://webcache.googleusercontent.com/search?q=cache:'+url
url = CRAWLERA_URL + urllib.urlencode({'url':url})
#urls.append(url)
url = urllib.unquote_plus(url)
url = SPLASH_URL + urllib.urlencode({'url': url})
#html = requests.get("http://localhost:8950/render.html?url={0}".format("https://facebook.com/guidespark")).text
html = requests.get(url).text

# %%
html
# Out:
# u'<!DOCTYPE html><html lang="en" id="facebook" class=""><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<base href="https://www.facebook.com/GuideSpark"><style type="text/css">body { margin-left:0;margin-right:0;margin-top:0; }#google-cache-hdr {background:#f5f5f5 !important;font:13px arial,sans-serif !important;text-align:left !important;color:#202020 !important;border:0 !important;margin:0 !important;border-bottom:1px solid #cecece !important;line-height:16px !important ;padding:16px 28px 24px 28px !important;}#google-cache-hdr * {display:inline !important;font:inherit !important;text-align:inherit !important;color:inherit !important;line-height:inherit !important;background:none !important;border:0 !important;margin:0 !important;padding:0 !important;letter-spacing:0 !important;}#google-cache-hdr a {text-decoration:none !important;color:#1a0dab !important;}#google-cache-hdr a:hover { text-decoration:underline !important; }#google-cache-hdr a:visited { col
# ...

# %%
#def _posts(self, html, api_key=""):
# &tbs=qdr:h,sbd:1 # &tbs=qdr:d,sbd:1 # &tbs=qdr:w,sbd:1
# &tbs=qdr:m,sbd:1 # &tbs=qdr:y,sbd:1
#html = Google().cache("https://www.facebook.com/Socceroos")
#html = Google().cache("https://facebook.com/guidespark")

fb = BeautifulSoup(html)

posts = []
for post in fb.find_all("div",{"class":"userContentWrapper"}):
    #utime = post.find("abbr",{"class":"livetimestamp"})
    
    utime = post.find("abbr")
    utime = utime["data-utime"] if utime else ""
    post_text = post.find("div",{"class":"userContent"}).text
    _post = {"timestamp":utime, "post_text":post_text}
    if post.find('div',{'class':'_3ekx'}):
      link_url = post.find('div',{'class':'_3ekx'}).find('a')
      if link_url:
          link_url = link_url["href"]
          link_url = urllib.unquote(link_url.split("l.php?u=")[-1])
      link_img = post.find('img',{"class":"scaledImageFitWidth"})
      link_img = link_img["src"] if link_img else ""
      link_title = post.find('div',{'class':'mbs'})
      link_title = link_title.text if link_title else ""
      link_summary = post.find('div',{'class':'_6m7'})
      link_summary = link_summary.text if link_summary else ""
      _post["link_url"], _post["link_img"] = link_url, link_img,
      _post["link_title"] = link_title
      _post["link_summary"] = link_summary
    posts.append(_post)
#return posts

# %%
html = Google().cache("https://linkedin.com/company/guidespark")

# %%
li = BeautifulSoup(html)
posts = []
for post in li.find_all("li",{"class":"feed-item"}):
    img = post.find("img")
    #img = img["src"] if img else ""
    try:
        img = img["src"] if "src" in img.keys() else ""
    except:
        img = None
    date = post.find("a", {"class":"nus-timestamp"}).text
    timestamp = Helper()._str_to_timestamp(date)
    post = post.find("span",{"class":"commentary"})
    try:
        link = [i.text for i in post.find_all("a")]
    except:
        continue
    data = {"img":img, "post":post.text, "link":link, "date":date,
            "timestamp":timestamp}
    #TODO - add timestamp
    posts.append(data)
#return posts

# %%
posts
# Out:
# [{'date': u'2 days ago',
#   'img': None,
#   'link': [],
#   'post': u"Thanks to Silicon Valley Business Journal for recognizing us in your Fastest-Growing Companies list for the second consecutive year- we're thrilled with our #7 spot! We have exciting job openings in Silicon Valley, plus Boston & New York- join us!",
#   'timestamp': 1445147705},
#  {'date': u'2 days ago',
#   'img': None,
#   'link': [],
#   'post': u"We're proud to be #7 in Silicon Valley's Fastest-Growing Private Companies list! Congratulations to our staff & thanks to our wonderful customers for getting us here. We're expanding fast across the US- check out our careers tab to join our team.",
#   'timestamp': 1445147705},
#  {'date': u'2 days ago',
#   'img': None,
#   'link': [],
#   'post': u"We're excited to be at Silicon Valley's Top 50 Fastest Growing Private Companies awards tonight - good luck to all our fellow nominees!",
#   'timestamp': 1445147705},
#  {'date': u'3 days ago',
#   'img': None,
# ...

# %%
html
# Out:
# u'<!DOCTYPE html>\n<html lang=en>\n  <meta charset=utf-8>\n  <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">\n  <title>Error 404 (Not Found)!!1</title>\n  <style>\n    *{margin:0;padding:0}html,code{font:15px/22px arial,sans-serif}html{background:#fff;color:#222;padding:15px}body{margin:7% auto 0;max-width:390px;min-height:180px;padding:30px 0 15px}* > body{background:url(//www.google.com/images/errors/robot.png) 100% 5px no-repeat;padding-right:205px}p{margin:11px 0 22px;overflow:hidden}ins{color:#777;text-decoration:none}a img{border:0}@media screen and (max-width:772px){body{background:none;margin-top:0;max-width:none;padding-right:0}}#logo{background:url(//www.google.com/images/branding/googlelogo/1x/googlelogo_color_150x54dp.png) no-repeat;margin-left:-5px}@media only screen and (min-resolution:192dpi){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat 0% 0%/100% 100%;-moz-border-image:
# ...

# %%
from companies import Companies
import pandas as pd
import rethinkdb as r
conn = r.connect(db="clearspark")

# %%
b = Companies()._company_blog("guidespark.com")
# Out:
#    date                                               link  \
# 0   NaN                    http://www.guidespark.com/blog/
# 1   NaN      http://www.guidespark.com/blog/category/blog/
# 2   NaN             http://www.guidespark.com/blog/page/2/
# 3   NaN  http://www.guidespark.com/blog/category/blog/p...
# 4   NaN             http://www.guidespark.com/blog/page/3/
# 5   NaN  http://www.guidespark.com/blog/category/blog/p...
# 6   NaN  http://www.guidespark.com/blog/category/blog/p...
# 7   NaN  http://www.guidespark.com/blog/category/blog/p...
# 8   NaN  http://www.guidespark.com/blog/category/blog/p...
# 9   NaN  http://www.guidespark.com/blog/category/blog/p...
# 10  NaN             http://www.guidespark.com/blog/page/5/
# 11  NaN            http://www.guidespark.com/blog/page/12/
# 12  NaN  http://www.guidespark.com/blog/category/blog/p...
# 13  NaN             http://www.guidespark.com/blog/page/6/
# 14  NaN  http://www.guidespark.com/blog/category/blog/p...
# ...

# %%
pd.DataFrame(b).event_key.drop_duplicates().shape
# Out:
# (99,)

# %%
r.table("events").insert(b).run(conn)
# Out:
# {u'deleted': 0,
#  u'errors': 100,
# ...

# %%
len(list(r.table("events").run(conn)))
# Out:
# 99

# %%
        # paginate
        jobs = "http://www.indeed.com/jobs?q={0}&sort=date".format(company_name)
        pages = requests.get(jobs).text
        data = Indeed()._search_results_html_to_df([pages])
        print data
        #TODO - add timestamp
        data = data.dropna()
        data["name_score"]=[fuzz.ratio(company_name, i) for i in data.company_name]
        data = data[data.name_score > 70]
        print data
        #date, timestamps = arrow.utcnow(), []
        if data.empty: return "NO HIRING"
        data["domain"] = company_domain
        data["event_type"] = "HiringEvent"
        data = data.applymap(lambda x: self._remove_non_ascii(x))
        data["event_key"] = ["".join(map(str, _data.to_dict().values()))[:124]
                             for i, _data in data.iterrows()]
        data = [row.dropna().to_dict() for i, row in data.iterrows()]
        r.table("events").insert(data).run(conn)
